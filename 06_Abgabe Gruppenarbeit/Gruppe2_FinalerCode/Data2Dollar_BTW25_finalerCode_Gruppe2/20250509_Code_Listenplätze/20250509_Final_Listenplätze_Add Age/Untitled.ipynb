# %%
import pandas as pd

# CSV-Datei einlesen
df = pd.read_csv("candidates_gender.csv", sep=';')

# %%
df.head()
# Out:
#   bundesland partei  listenplatz  nachname            vorname  \
# 0     Bayern    CSU            1  Dobrindt          Alexander
# 1     Bayern    CSU            2  Lindholz             Andrea
# 2     Bayern    CSU            3   Felßner            Günther
# 3     Bayern    CSU            4    Ludwig            Daniela
# 4     Bayern    CSU            5    Rainer  Alois Georg Josef
#
#                   beruf  geburtsjahr wahlkreis_name wahlkreis_nummer  Gender
# 0  MdB, Dipl.-Soziologe         1970       Weilheim              225    male
# 1   MdB, Rechtsanwältin         1970  Aschaffenburg              246  female
# 2              Landwirt         1966            NaN              NaN    male
# 3   MdB, Dipl.-Juristin         1975      Rosenheim              221  female
# 4   MdB, Metzgermeister         1965      Straubing              230    male

# %%
# Annahme: Die Spalte mit Geburtsjahren heißt 'Jahr'
# Neue Spalte 'Alter' berechnen
df["Alter"] = 2024 - df["geburtsjahr"]

# Neue CSV speichern
df.to_csv("final_listenplatz_mit_alter.csv", index=False)
